# %%
import pandas as pd
import numpy as np
import os

df_ntf = pd.read_csv('./dataset/netflix_a.csv', encoding='utf-8')
df_wtc = pd.read_csv('./dataset/watcha_a.csv', encoding='utf-8')
df_wvv = pd.read_csv('./dataset/wavve_a.csv', encoding='utf-8')
df_dnp = pd.read_csv('./dataset/disney_plus_a.csv', encoding='utf-8')
print(len(df_ntf), len(df_wtc), len(df_wvv), len(df_dnp))
# Out:
# 5665 7617 10723 1904

# %%
df = pd.concat([df_ntf, df_wtc, df_wvv, df_dnp], ignore_index=True)
del df['Unnamed: 0']
print(len(df))
df
# Out:
# 25909
#                        title  season  release_date  rate_jw  rate_imdb  \
# 0                   나이트 에이전트     1.0          2023       56        7.6
# 1                      체인소 맨     1.0          2022       96        8.5
# 2            Hell's Paradise     1.0          2023       50        8.6
# 3      귀멸의 칼날 - 카마도 탄지로 입지 편     NaN          2019       97        8.7
# 4            귀멸의 칼날 - 무한열차 편     NaN          2021       97        8.7
# ...                      ...     ...           ...      ...        ...
# 25904                     24     1.0          2001       90        8.4
# 25905                     24     2.0          2002       90        8.4
# 25906                     24     3.0          2003       90        8.4
# 25907                     24     4.0          2005       90        8.4
# 25908                     24     5.0          2006       90        8.4
#
#        popularity                                            genres  run_time  \
# 0           37000                              ['드라마', '액션', '스릴러']        49
# 1           33000  ['코미디', '애니메이션', '액션', 'SF', '판타지', '스릴러', '공포']        24
# 2               0  ['드라마', '액션', 'SF', '판타지', '스릴러', '공포', '애니메이션']        24
# 3          113000         ['SF', '애니메이션', '액션', '판타지', '스릴러', '공포']        24
# 4          113000         ['SF', '애니메이션', '액션', '판타지', '스릴러', '공포']        26
# ...           ...                                               ...       ...
# 25904      190000                        ['액션', '범죄', '드라마', '스릴러']        43
# 25905      190000                        ['액션', '범죄', '드라마', '스릴러']        45
# 25906      190000                        ['액션', '범죄', '드라마', '스릴러']        45
# 25907      190000                        ['액션', '범죄', '드라마', '스릴러']        44
# 25908      190000                        ['액션', '범죄', '드라마', '스릴러']        43
#
#        content_rating  episode_cnt  \
# 0                 NaN         10.0
# 1                19.0         12.0
# 2                 NaN          1.0
# 3                19.0         20.0
# 4                19.0         18.0
# ...               ...          ...
# 25904            15.0         20.0
# 25905            15.0         20.0
# 25906            15.0         20.0
# 25907            15.0         20.0
# 25908            15.0         20.0
#
#                                                 Synopsis  \
# 0                                                    NaN
# 1      '체인소의 악마'포치타와 함께 데블 헌터로 사는 소년 덴지.\n\n부모가 남긴 빚을...
# 2                                                    NaN
# 3      숯을 파는 마음씨 착한 소년 탄지로는, 어느 날 혈귀에게 가족을 몰살당한다.  유일...
# 4      나비저택에서의 치료를 마친 탄지로 일행은 단기간에 40명 이상의 사람이 행방불명이 ...
# ...                                                  ...
# 25904  The first season takes place on the day of the...
# 25905  The second season is set 18 months after seaso...
# 25906  The third season is set 3 years after season t...
# 25907  The fourth season is set 18 months after seaso...
# 25908  The fifth season is set 18 months after season...
#
#                                                   images  \
# 0      https://images.justwatch.com/poster/304465285/...
# 1      https://images.justwatch.com/poster/301084087/...
# 2      https://images.justwatch.com/poster/304485256/...
# 3      https://images.justwatch.com/poster/257186291/...
# 4      https://images.justwatch.com/poster/257186292/...
# ...                                                  ...
# 25904  https://images.justwatch.com/poster/246468229/...
# 25905  https://images.justwatch.com/poster/246468870/...
# 25906  https://images.justwatch.com/poster/246469111/...
# 25907  https://images.justwatch.com/poster/246470431/...
# 25908  https://images.justwatch.com/poster/246470719/...
#
#                                                backdrops  ott  \
# 0      https://www.justwatch.com/images/backdrop/3044...  1.0
# 1      https://www.justwatch.com/images/backdrop/3006...  1.0
# 2      https://www.justwatch.com/images/backdrop/2606...  1.0
# 3      https://www.justwatch.com/images/backdrop/1237...  1.0
# 4      https://www.justwatch.com/images/backdrop/1237...  1.0
# ...                                                  ...  ...
# 25904  https://www.justwatch.com/images/backdrop/2844...  4.0
# 25905  https://www.justwatch.com/images/backdrop/2844...  4.0
# 25906  https://www.justwatch.com/images/backdrop/2844...  4.0
# 25907  https://www.justwatch.com/images/backdrop/2844...  4.0
# 25908  https://www.justwatch.com/images/backdrop/2844...  4.0
#
#                                                     link
# 0      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 1      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 2      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 3      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 4      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# ...                                                  ...
# 25904  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...
# 25905  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...
# 25906  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 25907  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 25908  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...
#
# [25909 rows x 15 columns]

# %%
from collections import defaultdict
dictionary = defaultdict(list)
for idx in df.index:
    title = df.loc[idx, 'title']
    ott = df.loc[idx, 'ott']
    dictionary[title].append(ott)

for key, value in dictionary.items():
    dictionary[key] = list(set(value))

# %%
import os
savePath = os.getcwd() +'\\dataset'
title = list(dictionary.keys())
ott = list(dictionary.values())
df = pd.DataFrame({"title": title, "ott": ott})

# 본인이 맡은 파트의 ott 이름 + 시작 index + 끝 index 형식으로 파일 저장
df.to_csv(savePath+"\\tryingggg.csv", index=True, encoding='utf-8-sig')

# %%
ott_df = pd.read_csv('./dataset/tryingggg.csv', encoding='utf-8')
ott_df
# Out:
#        Unnamed: 0                  title         ott
# 0               0               나이트 에이전트       [1.0]
# 1               1                  체인소 맨  [1.0, 2.0]
# 2               2        Hell's Paradise       [1.0]
# 3               3  귀멸의 칼날 - 카마도 탄지로 입지 편  [1.0, 2.0]
# 4               4        귀멸의 칼날 - 무한열차 편  [1.0, 2.0]
# ...           ...                    ...         ...
# 16418       16418            아메리칸 호러 스토리       [4.0]
# 16419       16419    아메리칸 호러 스토리 - 더블 피처       [4.0]
# 16420       16420                 빛의 시네마       [4.0]
# 16421       16421              갓파더 오브 할렘       [4.0]
# 16422       16422                     24       [4.0]
#
# [16423 rows x 3 columns]

# %%
ott_df.ott = ott_df.ott.apply(tuple)
df = pd.merge(df, ott_df, left_on='title', right_on='title')
del df['Unnamed: 0']
df
# Out:
#                        title  season  release_date  rate_jw  rate_imdb  \
# 0                   나이트 에이전트     1.0          2023       56        7.6
# 1                      체인소 맨     1.0          2022       96        8.5
# 2                      체인소 맨     1.0          2022       96        8.5
# 3            Hell's Paradise     1.0          2023       50        8.6
# 4      귀멸의 칼날 - 카마도 탄지로 입지 편     NaN          2019       97        8.7
# ...                      ...     ...           ...      ...        ...
# 25904                     24     1.0          2001       90        8.4
# 25905                     24     2.0          2002       90        8.4
# 25906                     24     3.0          2003       90        8.4
# 25907                     24     4.0          2005       90        8.4
# 25908                     24     5.0          2006       90        8.4
#
#        popularity                                            genres  run_time  \
# 0           37000                              ['드라마', '액션', '스릴러']        49
# 1           33000  ['코미디', '애니메이션', '액션', 'SF', '판타지', '스릴러', '공포']        24
# 2           33000  ['코미디', '애니메이션', '액션', 'SF', '스릴러', '공포', '판타지']        24
# 3               0  ['드라마', '액션', 'SF', '판타지', '스릴러', '공포', '애니메이션']        24
# 4          113000         ['SF', '애니메이션', '액션', '판타지', '스릴러', '공포']        24
# ...           ...                                               ...       ...
# 25904      190000                        ['액션', '범죄', '드라마', '스릴러']        43
# 25905      190000                        ['액션', '범죄', '드라마', '스릴러']        45
# 25906      190000                        ['액션', '범죄', '드라마', '스릴러']        45
# 25907      190000                        ['액션', '범죄', '드라마', '스릴러']        44
# 25908      190000                        ['액션', '범죄', '드라마', '스릴러']        43
#
#        content_rating  episode_cnt  \
# 0                 NaN         10.0
# 1                19.0         12.0
# 2                19.0         12.0
# 3                 NaN          1.0
# 4                19.0         20.0
# ...               ...          ...
# 25904            15.0         20.0
# 25905            15.0         20.0
# 25906            15.0         20.0
# 25907            15.0         20.0
# 25908            15.0         20.0
#
#                                                 Synopsis  \
# 0                                                    NaN
# 1      '체인소의 악마'포치타와 함께 데블 헌터로 사는 소년 덴지.\n\n부모가 남긴 빚을...
# 2      '체인소의 악마'포치타와 함께 데블 헌터로 사는 소년 덴지.\n\n부모가 남긴 빚을...
# 3                                                    NaN
# 4      숯을 파는 마음씨 착한 소년 탄지로는, 어느 날 혈귀에게 가족을 몰살당한다.  유일...
# ...                                                  ...
# 25904  The first season takes place on the day of the...
# 25905  The second season is set 18 months after seaso...
# 25906  The third season is set 3 years after season t...
# 25907  The fourth season is set 18 months after seaso...
# 25908  The fifth season is set 18 months after season...
#
#                                                   images  \
# 0      https://images.justwatch.com/poster/304465285/...
# 1      https://images.justwatch.com/poster/301084087/...
# 2      https://images.justwatch.com/poster/301084087/...
# 3      https://images.justwatch.com/poster/304485256/...
# 4      https://images.justwatch.com/poster/257186291/...
# ...                                                  ...
# 25904  https://images.justwatch.com/poster/246468229/...
# 25905  https://images.justwatch.com/poster/246468870/...
# 25906  https://images.justwatch.com/poster/246469111/...
# 25907  https://images.justwatch.com/poster/246470431/...
# 25908  https://images.justwatch.com/poster/246470719/...
#
#                                                backdrops  ott_x  \
# 0      https://www.justwatch.com/images/backdrop/3044...    1.0
# 1      https://www.justwatch.com/images/backdrop/3006...    1.0
# 2      https://www.justwatch.com/images/backdrop/3006...    2.0
# 3      https://www.justwatch.com/images/backdrop/2606...    1.0
# 4      https://www.justwatch.com/images/backdrop/1237...    1.0
# ...                                                  ...    ...
# 25904  https://www.justwatch.com/images/backdrop/2844...    4.0
# 25905  https://www.justwatch.com/images/backdrop/2844...    4.0
# 25906  https://www.justwatch.com/images/backdrop/2844...    4.0
# 25907  https://www.justwatch.com/images/backdrop/2844...    4.0
# 25908  https://www.justwatch.com/images/backdrop/2844...    4.0
#
#                                                     link  \
# 0      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 1      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 2      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 3      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 4      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# ...                                                  ...
# 25904  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...
# 25905  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...
# 25906  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 25907  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...
# 25908  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...
#
#                                 ott_y
# 0                     ([, 1, ., 0, ])
# 1      ([, 1, ., 0, ,,  , 2, ., 0, ])
# 2      ([, 1, ., 0, ,,  , 2, ., 0, ])
# 3                     ([, 1, ., 0, ])
# 4      ([, 1, ., 0, ,,  , 2, ., 0, ])
# ...                               ...
# 25904                 ([, 4, ., 0, ])
# 25905                 ([, 4, ., 0, ])
# 25906                 ([, 4, ., 0, ])
# 25907                 ([, 4, ., 0, ])
# 25908                 ([, 4, ., 0, ])
#
# [25909 rows x 16 columns]

# %%
import pandas as pd
import re

# 숫자 부분 추출하는 함수 정의
def extract_numbers(string):
    # print('input : ',string)
    pattern = r'\d+\.*\d*'  # 정규식 패턴: 숫자와 옵션으로 소수점(.)이 포함된 패턴
    numbers = re.findall(pattern, ''.join(string))  # 정규식 패턴에 해당하는 부분 추출
    return [int(float(num)) for num in numbers]  # 추출된 문자열을 숫자형으로 변환하여 리스트 반환

# 'ott_y' 컬럼의 값을 숫자 리스트로 변환
df['ott_y'] = df['ott_y'].apply(extract_numbers)

# %%
# NaN 값들을 전부 0으로 바꿔주기
df.fillna(0, inplace=True)
df
# Out:
#                        title  season  release_date  rate_jw  rate_imdb  \
# 0                   나이트 에이전트     1.0          2023       56        7.6
# 1                      체인소 맨     1.0          2022       96        8.5
# 2                      체인소 맨     1.0          2022       96        8.5
# 3            Hell's Paradise     1.0          2023       50        8.6
# 4      귀멸의 칼날 - 카마도 탄지로 입지 편     0.0          2019       97        8.7
# ...                      ...     ...           ...      ...        ...
# 25904                     24     1.0          2001       90        8.4
# 25905                     24     2.0          2002       90        8.4
# 25906                     24     3.0          2003       90        8.4
# 25907                     24     4.0          2005       90        8.4
# 25908                     24     5.0          2006       90        8.4
#
#        popularity                                            genres  run_time  \
# 0           37000                              ['드라마', '액션', '스릴러']        49
# 1           33000  ['코미디', '애니메이션', '액션', 'SF', '판타지', '스릴러', '공포']        24
# 2           33000  ['코미디', '애니메이션', '액션', 'SF', '스릴러', '공포', '판타지']        24
# 3               0  ['드라마', '액션', 'SF', '판타지', '스릴러', '공포', '애니메이션']        24
# 4          113000         ['SF', '애니메이션', '액션', '판타지', '스릴러', '공포']        24
# ...           ...                                               ...       ...
# 25904      190000                        ['액션', '범죄', '드라마', '스릴러']        43
# 25905      190000                        ['액션', '범죄', '드라마', '스릴러']        45
# 25906      190000                        ['액션', '범죄', '드라마', '스릴러']        45
# 25907      190000                        ['액션', '범죄', '드라마', '스릴러']        44
# 25908      190000                        ['액션', '범죄', '드라마', '스릴러']        43
#
#        content_rating  episode_cnt  \
# 0                 0.0         10.0
# 1                19.0         12.0
# 2                19.0         12.0
# 3                 0.0          1.0
# 4                19.0         20.0
# ...               ...          ...
# 25904            15.0         20.0
# 25905            15.0         20.0
# 25906            15.0         20.0
# 25907            15.0         20.0
# 25908            15.0         20.0
#
#                                                 Synopsis  \
# 0                                                      0
# 1      '체인소의 악마'포치타와 함께 데블 헌터로 사는 소년 덴지.\n\n부모가 남긴 빚을...
# 2      '체인소의 악마'포치타와 함께 데블 헌터로 사는 소년 덴지.\n\n부모가 남긴 빚을...
# 3                                                      0
# 4      숯을 파는 마음씨 착한 소년 탄지로는, 어느 날 혈귀에게 가족을 몰살당한다.  유일...
# ...                                                  ...
# 25904  The first season takes place on the day of the...
# 25905  The second season is set 18 months after seaso...
# 25906  The third season is set 3 years after season t...
# 25907  The fourth season is set 18 months after seaso...
# 25908  The fifth season is set 18 months after season...
#
#                                                   images  \
# 0      https://images.justwatch.com/poster/304465285/...
# 1      https://images.justwatch.com/poster/301084087/...
# 2      https://images.justwatch.com/poster/301084087/...
# 3      https://images.justwatch.com/poster/304485256/...
# 4      https://images.justwatch.com/poster/257186291/...
# ...                                                  ...
# 25904  https://images.justwatch.com/poster/246468229/...
# 25905  https://images.justwatch.com/poster/246468870/...
# 25906  https://images.justwatch.com/poster/246469111/...
# 25907  https://images.justwatch.com/poster/246470431/...
# 25908  https://images.justwatch.com/poster/246470719/...
#
#                                                backdrops  ott_x  \
# 0      https://www.justwatch.com/images/backdrop/3044...    1.0
# 1      https://www.justwatch.com/images/backdrop/3006...    1.0
# 2      https://www.justwatch.com/images/backdrop/3006...    2.0
# 3      https://www.justwatch.com/images/backdrop/2606...    1.0
# 4      https://www.justwatch.com/images/backdrop/1237...    1.0
# ...                                                  ...    ...
# 25904  https://www.justwatch.com/images/backdrop/2844...    4.0
# 25905  https://www.justwatch.com/images/backdrop/2844...    4.0
# 25906  https://www.justwatch.com/images/backdrop/2844...    4.0
# 25907  https://www.justwatch.com/images/backdrop/2844...    4.0
# 25908  https://www.justwatch.com/images/backdrop/2844...    4.0
#
#                                                     link   ott_y
# 0      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [1]
# 1      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# 2      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# 3      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [1]
# 4      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# ...                                                  ...     ...
# 25904  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
# 25905  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
# 25906  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [4]
# 25907  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [4]
# 25908  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
#
# [25909 rows x 16 columns]

# %%
df[['season', 'ott_x', 'episode_cnt']] = df[['season', 'ott_x', 'episode_cnt']].astype(int)
df
# Out:
#                        title  season  release_date  rate_jw  rate_imdb  \
# 0                   나이트 에이전트       1          2023       56        7.6
# 1                      체인소 맨       1          2022       96        8.5
# 2                      체인소 맨       1          2022       96        8.5
# 3            Hell's Paradise       1          2023       50        8.6
# 4      귀멸의 칼날 - 카마도 탄지로 입지 편       0          2019       97        8.7
# ...                      ...     ...           ...      ...        ...
# 25904                     24       1          2001       90        8.4
# 25905                     24       2          2002       90        8.4
# 25906                     24       3          2003       90        8.4
# 25907                     24       4          2005       90        8.4
# 25908                     24       5          2006       90        8.4
#
#        popularity                                            genres  run_time  \
# 0           37000                              ['드라마', '액션', '스릴러']        49
# 1           33000  ['코미디', '애니메이션', '액션', 'SF', '판타지', '스릴러', '공포']        24
# 2           33000  ['코미디', '애니메이션', '액션', 'SF', '스릴러', '공포', '판타지']        24
# 3               0  ['드라마', '액션', 'SF', '판타지', '스릴러', '공포', '애니메이션']        24
# 4          113000         ['SF', '애니메이션', '액션', '판타지', '스릴러', '공포']        24
# ...           ...                                               ...       ...
# 25904      190000                        ['액션', '범죄', '드라마', '스릴러']        43
# 25905      190000                        ['액션', '범죄', '드라마', '스릴러']        45
# 25906      190000                        ['액션', '범죄', '드라마', '스릴러']        45
# 25907      190000                        ['액션', '범죄', '드라마', '스릴러']        44
# 25908      190000                        ['액션', '범죄', '드라마', '스릴러']        43
#
#        content_rating  episode_cnt  \
# 0                 0.0           10
# 1                19.0           12
# 2                19.0           12
# 3                 0.0            1
# 4                19.0           20
# ...               ...          ...
# 25904            15.0           20
# 25905            15.0           20
# 25906            15.0           20
# 25907            15.0           20
# 25908            15.0           20
#
#                                                 Synopsis  \
# 0                                                      0
# 1      '체인소의 악마'포치타와 함께 데블 헌터로 사는 소년 덴지.\n\n부모가 남긴 빚을...
# 2      '체인소의 악마'포치타와 함께 데블 헌터로 사는 소년 덴지.\n\n부모가 남긴 빚을...
# 3                                                      0
# 4      숯을 파는 마음씨 착한 소년 탄지로는, 어느 날 혈귀에게 가족을 몰살당한다.  유일...
# ...                                                  ...
# 25904  The first season takes place on the day of the...
# 25905  The second season is set 18 months after seaso...
# 25906  The third season is set 3 years after season t...
# 25907  The fourth season is set 18 months after seaso...
# 25908  The fifth season is set 18 months after season...
#
#                                                   images  \
# 0      https://images.justwatch.com/poster/304465285/...
# 1      https://images.justwatch.com/poster/301084087/...
# 2      https://images.justwatch.com/poster/301084087/...
# 3      https://images.justwatch.com/poster/304485256/...
# 4      https://images.justwatch.com/poster/257186291/...
# ...                                                  ...
# 25904  https://images.justwatch.com/poster/246468229/...
# 25905  https://images.justwatch.com/poster/246468870/...
# 25906  https://images.justwatch.com/poster/246469111/...
# 25907  https://images.justwatch.com/poster/246470431/...
# 25908  https://images.justwatch.com/poster/246470719/...
#
#                                                backdrops  ott_x  \
# 0      https://www.justwatch.com/images/backdrop/3044...      1
# 1      https://www.justwatch.com/images/backdrop/3006...      1
# 2      https://www.justwatch.com/images/backdrop/3006...      2
# 3      https://www.justwatch.com/images/backdrop/2606...      1
# 4      https://www.justwatch.com/images/backdrop/1237...      1
# ...                                                  ...    ...
# 25904  https://www.justwatch.com/images/backdrop/2844...      4
# 25905  https://www.justwatch.com/images/backdrop/2844...      4
# 25906  https://www.justwatch.com/images/backdrop/2844...      4
# 25907  https://www.justwatch.com/images/backdrop/2844...      4
# 25908  https://www.justwatch.com/images/backdrop/2844...      4
#
#                                                     link   ott_y
# 0      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [1]
# 1      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# 2      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# 3      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [1]
# 4      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# ...                                                  ...     ...
# 25904  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
# 25905  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
# 25906  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [4]
# 25907  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [4]
# 25908  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
#
# [25909 rows x 16 columns]

# %%
import ast
import re

# 데이터프레임에서 'genre' 컬럼의 모든 값을 추출하여 리스트로 만듦
lst = df['genres'].tolist()

result = []
for elem in lst:
    # 문자열을 리스트로 변환
    elem.replace(' ','')
    lst_elem = ast.literal_eval(elem)
    # print(lst_elem)
    # 알파벳만 추출하여 리스트에 추가
    elem_result = []
    for sub_elem in lst_elem:
        elem_result.append(''.join(re.findall('[a-zA-Z]+', sub_elem)))
        elem_result.extend(re.findall('[ㄱ-ㅣ가-힣]+', sub_elem))
    res = []
    for e in elem_result:
        if e == '':
            continue
        else:
            res.append(e)
    # print(result)
    result.append(res)
len(result)
# 결과 리스트를 데이터프레임의 'genre' 컬럼으로 할당
df['genres'] = result
df
# Out:
#                        title  season  release_date  rate_jw  rate_imdb  \
# 0                   나이트 에이전트       1          2023       56        7.6
# 1                      체인소 맨       1          2022       96        8.5
# 2                      체인소 맨       1          2022       96        8.5
# 3            Hell's Paradise       1          2023       50        8.6
# 4      귀멸의 칼날 - 카마도 탄지로 입지 편       0          2019       97        8.7
# ...                      ...     ...           ...      ...        ...
# 25904                     24       1          2001       90        8.4
# 25905                     24       2          2002       90        8.4
# 25906                     24       3          2003       90        8.4
# 25907                     24       4          2005       90        8.4
# 25908                     24       5          2006       90        8.4
#
#        popularity                              genres  run_time  \
# 0           37000                      [드라마, 액션, 스릴러]        49
# 1           33000  [코미디, 애니메이션, 액션, SF, 판타지, 스릴러, 공포]        24
# 2           33000  [코미디, 애니메이션, 액션, SF, 스릴러, 공포, 판타지]        24
# 3               0  [드라마, 액션, SF, 판타지, 스릴러, 공포, 애니메이션]        24
# 4          113000       [SF, 애니메이션, 액션, 판타지, 스릴러, 공포]        24
# ...           ...                                 ...       ...
# 25904      190000                  [액션, 범죄, 드라마, 스릴러]        43
# 25905      190000                  [액션, 범죄, 드라마, 스릴러]        45
# 25906      190000                  [액션, 범죄, 드라마, 스릴러]        45
# 25907      190000                  [액션, 범죄, 드라마, 스릴러]        44
# 25908      190000                  [액션, 범죄, 드라마, 스릴러]        43
#
#        content_rating  episode_cnt  \
# 0                 0.0           10
# 1                19.0           12
# 2                19.0           12
# 3                 0.0            1
# 4                19.0           20
# ...               ...          ...
# 25904            15.0           20
# 25905            15.0           20
# 25906            15.0           20
# 25907            15.0           20
# 25908            15.0           20
#
#                                                 Synopsis  \
# 0                                                      0
# 1      '체인소의 악마'포치타와 함께 데블 헌터로 사는 소년 덴지.\n\n부모가 남긴 빚을...
# 2      '체인소의 악마'포치타와 함께 데블 헌터로 사는 소년 덴지.\n\n부모가 남긴 빚을...
# 3                                                      0
# 4      숯을 파는 마음씨 착한 소년 탄지로는, 어느 날 혈귀에게 가족을 몰살당한다.  유일...
# ...                                                  ...
# 25904  The first season takes place on the day of the...
# 25905  The second season is set 18 months after seaso...
# 25906  The third season is set 3 years after season t...
# 25907  The fourth season is set 18 months after seaso...
# 25908  The fifth season is set 18 months after season...
#
#                                                   images  \
# 0      https://images.justwatch.com/poster/304465285/...
# 1      https://images.justwatch.com/poster/301084087/...
# 2      https://images.justwatch.com/poster/301084087/...
# 3      https://images.justwatch.com/poster/304485256/...
# 4      https://images.justwatch.com/poster/257186291/...
# ...                                                  ...
# 25904  https://images.justwatch.com/poster/246468229/...
# 25905  https://images.justwatch.com/poster/246468870/...
# 25906  https://images.justwatch.com/poster/246469111/...
# 25907  https://images.justwatch.com/poster/246470431/...
# 25908  https://images.justwatch.com/poster/246470719/...
#
#                                                backdrops  ott_x  \
# 0      https://www.justwatch.com/images/backdrop/3044...      1
# 1      https://www.justwatch.com/images/backdrop/3006...      1
# 2      https://www.justwatch.com/images/backdrop/3006...      2
# 3      https://www.justwatch.com/images/backdrop/2606...      1
# 4      https://www.justwatch.com/images/backdrop/1237...      1
# ...                                                  ...    ...
# 25904  https://www.justwatch.com/images/backdrop/2844...      4
# 25905  https://www.justwatch.com/images/backdrop/2844...      4
# 25906  https://www.justwatch.com/images/backdrop/2844...      4
# 25907  https://www.justwatch.com/images/backdrop/2844...      4
# 25908  https://www.justwatch.com/images/backdrop/2844...      4
#
#                                                     link   ott_y
# 0      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [1]
# 1      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# 2      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# 3      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [1]
# 4      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# ...                                                  ...     ...
# 25904  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
# 25905  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
# 25906  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [4]
# 25907  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [4]
# 25908  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
#
# [25909 rows x 16 columns]

# %%
del df['ott_x']
df
# Out:
#                        title  season  release_date  rate_jw  rate_imdb  \
# 0                   나이트 에이전트       1          2023       56        7.6
# 1                      체인소 맨       1          2022       96        8.5
# 2                      체인소 맨       1          2022       96        8.5
# 3            Hell's Paradise       1          2023       50        8.6
# 4      귀멸의 칼날 - 카마도 탄지로 입지 편       0          2019       97        8.7
# ...                      ...     ...           ...      ...        ...
# 25904                     24       1          2001       90        8.4
# 25905                     24       2          2002       90        8.4
# 25906                     24       3          2003       90        8.4
# 25907                     24       4          2005       90        8.4
# 25908                     24       5          2006       90        8.4
#
#        popularity                              genres  run_time  \
# 0           37000                      [드라마, 액션, 스릴러]        49
# 1           33000  [코미디, 애니메이션, 액션, SF, 판타지, 스릴러, 공포]        24
# 2           33000  [코미디, 애니메이션, 액션, SF, 스릴러, 공포, 판타지]        24
# 3               0  [드라마, 액션, SF, 판타지, 스릴러, 공포, 애니메이션]        24
# 4          113000       [SF, 애니메이션, 액션, 판타지, 스릴러, 공포]        24
# ...           ...                                 ...       ...
# 25904      190000                  [액션, 범죄, 드라마, 스릴러]        43
# 25905      190000                  [액션, 범죄, 드라마, 스릴러]        45
# 25906      190000                  [액션, 범죄, 드라마, 스릴러]        45
# 25907      190000                  [액션, 범죄, 드라마, 스릴러]        44
# 25908      190000                  [액션, 범죄, 드라마, 스릴러]        43
#
#        content_rating  episode_cnt  \
# 0                 0.0           10
# 1                19.0           12
# 2                19.0           12
# 3                 0.0            1
# 4                19.0           20
# ...               ...          ...
# 25904            15.0           20
# 25905            15.0           20
# 25906            15.0           20
# 25907            15.0           20
# 25908            15.0           20
#
#                                                 Synopsis  \
# 0                                                      0
# 1      '체인소의 악마'포치타와 함께 데블 헌터로 사는 소년 덴지.\n\n부모가 남긴 빚을...
# 2      '체인소의 악마'포치타와 함께 데블 헌터로 사는 소년 덴지.\n\n부모가 남긴 빚을...
# 3                                                      0
# 4      숯을 파는 마음씨 착한 소년 탄지로는, 어느 날 혈귀에게 가족을 몰살당한다.  유일...
# ...                                                  ...
# 25904  The first season takes place on the day of the...
# 25905  The second season is set 18 months after seaso...
# 25906  The third season is set 3 years after season t...
# 25907  The fourth season is set 18 months after seaso...
# 25908  The fifth season is set 18 months after season...
#
#                                                   images  \
# 0      https://images.justwatch.com/poster/304465285/...
# 1      https://images.justwatch.com/poster/301084087/...
# 2      https://images.justwatch.com/poster/301084087/...
# 3      https://images.justwatch.com/poster/304485256/...
# 4      https://images.justwatch.com/poster/257186291/...
# ...                                                  ...
# 25904  https://images.justwatch.com/poster/246468229/...
# 25905  https://images.justwatch.com/poster/246468870/...
# 25906  https://images.justwatch.com/poster/246469111/...
# 25907  https://images.justwatch.com/poster/246470431/...
# 25908  https://images.justwatch.com/poster/246470719/...
#
#                                                backdrops  \
# 0      https://www.justwatch.com/images/backdrop/3044...
# 1      https://www.justwatch.com/images/backdrop/3006...
# 2      https://www.justwatch.com/images/backdrop/3006...
# 3      https://www.justwatch.com/images/backdrop/2606...
# 4      https://www.justwatch.com/images/backdrop/1237...
# ...                                                  ...
# 25904  https://www.justwatch.com/images/backdrop/2844...
# 25905  https://www.justwatch.com/images/backdrop/2844...
# 25906  https://www.justwatch.com/images/backdrop/2844...
# 25907  https://www.justwatch.com/images/backdrop/2844...
# 25908  https://www.justwatch.com/images/backdrop/2844...
#
#                                                     link   ott_y
# 0      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [1]
# 1      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# 2      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# 3      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [1]
# 4      https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...  [1, 2]
# ...                                                  ...     ...
# 25904  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
# 25905  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
# 25906  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [4]
# 25907  https://www.justwatch.com/kr/TV-%ED%94%84%EB%A...     [4]
# 25908  https://www.justwatch.com/kr/%EC%98%81%ED%99%9...     [4]
#
# [25909 rows x 15 columns]

# %%
import os
savePath = os.getcwd() +'\\dataset'

# 본인이 맡은 파트의 ott 이름 + 시작 index + 끝 index 형식으로 파일 저장
df.to_csv(savePath+"\\db_dataset.csv", index=True, encoding='utf-8-sig')
